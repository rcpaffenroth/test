# %% [markdown]
# <a href="https://colab.research.google.com/github/rcpaffenroth/test/blob/master/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('2+2')
